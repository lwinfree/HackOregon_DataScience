# %%
#graph fields of study changes per year 1985-2015, every 5 years
#use data table 12
#then break it down by sex (table 14)
#break it down by ethnicity, race & citizenship table 17 & 19
#age for diff fields, diff sexes, diff races table 27 
#functional limitations table 28
#went to community college table 30
#median years to degree table 31
#medan years to degree by sex, citizen, ethnicity, race, field table 32
#parents education by race etc table 33
#financial support table 35 & 37
#education related debt by race etc table 40
#employment sectors table 46
#median salary by sex, field table 48
#table 54 has a good overview of general stats: sex, age, marital status etc

# %%
import pandas as pd
demData = pd.read_csv('/Users/winfree/tab12_grad_data.csv')

# %%
demData.head()
# Out:
#                                 Field of study    1985 Unnamed: 2    1990  \
# 0                                          NaN  Number    Percent  Number
# 1                                   All fields  31,295     100.0%  36,065
# 2                                Life sciences   5,822      18.6%   6,655
# 3  Agricultural sciences and natural resources   1,300       4.2%   1,371
# 4           Biological and biomedical sciences   3,793      12.1%   4,328
#
#   Unnamed: 4    1995 Unnamed: 6    2000 Unnamed: 8    2005 Unnamed: 10  \
# 0    Percent  Number    Percent  Number    Percent  Number     Percent
# 1     100.0%  41,747     100.0%  41,369     100.0%  43,385      100.0%
# 2      18.5%   7,998      19.2%   8,622      20.8%   9,310       21.5%
# 3       3.8%   1,293       3.1%   1,179       2.8%   1,160        2.7%
# 4      12.0%   5,376      12.9%   5,853      14.1%   6,367       14.7%
#
#      2010 Unnamed: 12    2015 Unnamed: 14
# 0  Number     Percent  Number     Percent
# ...

# %%
demData['Field of study'][1]
# Out:
# 'All fields'

# %%
demIndex = ('85','90','95', '00')

# %%
allFields = pd.DataFrame({'A':demData['1985'][1], 'B':demData['1990'][1], 'C':demData['1995'][1], 'D':demData['2000'][1]}, index = demIndex)

# %%
allFields
# Out:
#          A       B       C       D
# 85  31,295  36,065  41,747  41,369
# 90  31,295  36,065  41,747  41,369
# 95  31,295  36,065  41,747  41,369
# 00  31,295  36,065  41,747  41,369

# %%
fields = demData['Field of study']

# %%
demData.describe
# Out:
# <bound method NDFrame.describe of                                        Field of study    1985 Unnamed: 2  \
# 0                                                 NaN  Number    Percent
# 1                                          All fields  31,295     100.0%
# 2                                       Life sciences   5,822      18.6%
# 3         Agricultural sciences and natural resources   1,300       4.2%
# 4                  Biological and biomedical sciences   3,793      12.1%
# 5                                     Health sciences     729       2.3%
# 6                Physical sciences and earth sciences   3,491      11.2%
# 7                                           Chemistry   1,836       5.9%
# 8        Geosciences, atmospheric, and ocean sciences     575       1.8%
# 9                               Physics and astronomy   1,080       3.5%
# 10                  Mathematics and computer sciences     998       3.2%
# ...
